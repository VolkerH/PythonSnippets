# %% [markdown]
# Eliot
# See:
# * https://pythonspeed.com/articles/logging-for-scientific-computing/
# * https://eliot.readthedocs.io/en/stable/index.html
#
# also needs [eliottree](https://github.com/jonathanj/eliottree)

# %%
from eliot import log_call, to_file
to_file(open("out.log", "w"))

@log_call
def fib(n):
    if n==0 or n==1:
        return 1
    else:
        return fib(n-1) + fib(n-2)

# %%
fib(10)
# Out:
# 89

# %%
# !eliot-tree  out.log
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Volker\Anaconda3\Scripts\eliot-tree-script.py", line 11, in <module>
#     load_entry_point('eliot-tree==18.1.1', 'console_scripts', 'eliot-tree')()
#   File "C:\Users\Volker\Anaconda3\lib\site-packages\eliot_tree-18.1.1-py3.5.egg\eliottree\_cli.py", line 178, in main
#     human_readable=args.human_readable)
#   File "C:\Users\Volker\Anaconda3\lib\site-packages\eliot_tree-18.1.1-py3.5.egg\eliottree\_cli.py", line 92, in display_tasks
#     colorize=colorize)
#   File "C:\Users\Volker\Anaconda3\lib\site-packages\eliot_tree-18.1.1-py3.5.egg\eliottree\_render.py", line 265, in render_tasks
#     write(format_tree(task, _format_node, _get_children))
#   File "C:\Users\Volker\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 38-40: character maps to <undefined>

# %% [markdown]
# This doesn't seem to work in Jupyter.
# Pasting output from the console. Might be quite useful for profiling as well.
#
#
# ```
#
# (spimenv) λ eliot-tree.exe out.log
#
# db4c0436-2002-43bc-905c-60a7b9d5d67e
#
# └── __main__.fib/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.032s
#
#     ├── n: 10
#
#     ├── __main__.fib/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.020s
#
#     │   ├── n: 9
#
#     │   ├── __main__.fib/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.011s
#
#     │   │   ├── n: 8
#
#     │   │   ├── __main__.fib/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.007s
#
#     │   │   │   ├── n: 7
#
#     │   │   │   ├── __main__.fib/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.005s
#
#     │   │   │   │   ├── n: 6
#
#     │   │   │   │   ├── __main__.fib/2/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.003s
#
#     │   │   │   │   │   ├── n: 5
#
#     │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.002s
#
#     │   │   │   │   │   │   ├── n: 4
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   ├── n: 3
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/2/2/2/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   │   ├── n: 0
#
#     │   │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/2/2/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 2
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/2/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 3
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/3/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/3/2/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/2/3/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   │   ├── n: 0
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/3/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/3/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 2
#
#     │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │       └── result: 5
#
#     │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   ├── n: 3
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/3/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/3/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/3/2/2/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/3/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 0
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/3/2/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/3/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 2
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/2/3/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/3/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   └── __main__.fib/2/2/2/2/2/3/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │       └── result: 3
#
#     │   │   │   │   │   └── __main__.fib/2/2/2/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │       └── result: 8
#
#     │   │   │   │   ├── __main__.fib/2/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.002s
#
#     │   │   │   │   │   ├── n: 4
#
#     │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   ├── n: 3
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/2/2/2/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   │   ├── n: 0
#
#     │   │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/2/2/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 2
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/2/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │       └── result: 3
#
#     │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/3/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   ├── n: 1
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/3/2/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/2/3/3/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#     │   │   │   │   │   │   │   ├── n: 0
#
#     │   │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/3/3/2 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │   │       └── result: 1
#
#     │   │   │   │   │   │   └── __main__.fib/2/2/2/2/3/3/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │   │       └── result: 2
#
#     │   │   │   │   │   └── __main__.fib/2/2/2/2/3/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │   │       └── result: 5
#
#     │   │   │   │   └── __main__.fib/2/2/2/2/4 ⇒ succeeded 2019-05-03 05:35:52
#
#     │   │   │   │       └── result: 13
#
#     │   │   │   ├── __main__.fib/2/2/2/3/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.002s
#
#     │   │   │   │   ├── n: 5
#
#     │   │   │   │   ├── __main__.fib/2/2/2/3/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   ├── n: 4
#
#     │   │   │   │   │   ├── __main__.fib/2/2/2/3/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   ├── n: 3
#
#     │   │   │   │   │   │   ├── __main__.fib/2/2/2/3/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.001s
#
#     │   │   │   │   │   │   │   ├── n: 2
#
#     │   │   │   │   │   │   │   ├── __main__.fib/2/2/2/3/2/2/2/2/1 ⇒ started 2019-05-03 05:35:52 ⧖ 0.000s
#
#
# ```

# %% [markdown]
# ## Does this logging also work if we run function caching ?

# %%
import functools

# %%
to_file(open("out_cached.log", "w"))

@log_call
@functools.lru_cache(maxsize=5)
def cached_fib(n):
    if n==0 or n==1:
        return 1
    else:
        return cached_fib(n-1) + cached_fib(n-2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\volker\anaconda3\envs\spimenv\lib\inspect.py in getfullargspec(func)
#    1118                                        skip_bound_arg=False,
# -> 1119                                        sigcls=Signature)
#    1120     except Exception as ex:
#
# c:\users\volker\anaconda3\envs\spimenv\lib\inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2265         return _signature_from_builtin(sigcls, obj,
# -> 2266                                        skip_bound_arg=skip_bound_arg)
#    2267
#
# c:\users\volker\anaconda3\envs\spimenv\lib\inspect.py in _signature_from_builtin(cls, func, skip_bound_arg)
#    2089     if not s:
# -> 2090         raise ValueError("no signature found for builtin {!r}".format(func))
#    2091
#
# ...

# %% [markdown]
# ... apparently not. Is this specific to function caching or would that also not work with other decorators?|

# %%
import pandas as pd
# %matplotlib inline

# %%
# this is a typical Cellprofiler results table
df = pd.read_csv("C:/Users/Volker/OleksIntensityImage.csv")

# %%
# group by the different positions
gr = df.groupby(["Metadata_Pos"])

# %%
# Metadata_Nr2 has the different experiment numbers, 4 and 30 are controls
gr.plot(x="Metadata_Nr2",
        y=["Intensity_MeanIntensity_Dapi", "Intensity_MeanIntensity_Tritc"],
        kind="bar", 
        color=["blue","red"],
        figsize=(10,5)
       )
# Out:
# Metadata_Pos
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

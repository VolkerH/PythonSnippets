# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Volker/OleksIntensityImage.csv")

# %%
gr = df.groupby(["Metadata_Pos"])

# %%
gr.plot(x="Metadata_Nr2",y=["Intensity_MeanIntensity_Dapi", "Intensity_MeanIntensity_Tritc"], kind="bar", color=["blue","red"])
# Out:
# Metadata_Pos
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
